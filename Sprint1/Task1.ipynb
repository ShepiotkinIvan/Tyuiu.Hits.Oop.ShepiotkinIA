// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    private string _color;
    private int _speed;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public int Speed
    {
        get { return _speed; }
        set
        {
            if (value >= 0)
            _speed = value;
            else
            throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
        }
    }

    public static int TotalVehicles { get; private set; } = 0;

    public Vehicle()
    {
        TotalVehicles++;
    }

    public void Accelerate(int delta)
    {
        Speed += delta;
    }

    public static void DisplayTotalVehicles()
    {
        Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
    }
}

public class Car : Vehicle
{
    private int _fuelLevel;

    public int FuelLevel
    {
        get { return _fuelLevel; }
        set { _fuelLevel = value; }
    }

    public Car() : base()
    {
        FuelLevel = 100;
    }

    public void Refuel(int amount)
    {
        FuelLevel += amount;
    }
}

Car FirstCar = new Car();
FirstCar.Color = "Красный";
FirstCar.Accelerate(50);
FirstCar.Refuel(20);

Car SecondCar = new Car();
SecondCar.Color = "Синий";
SecondCar.Accelerate(70);
SecondCar.Refuel(30);

Vehicle.DisplayTotalVehicles();

Console.WriteLine($"Первая машина - Цвет: {FirstCar.Color}, Скорость: {FirstCar.Speed}, Уровень топлива: {FirstCar.FuelLevel}");
Console.WriteLine($"Вторая машина - Цвет: {SecondCar.Color}, Скорость: {SecondCar.Speed}, Уровень топлива: {SecondCar.FuelLevel}");
// Out:
// Общее количество транспортных средств: 2
// Первая машина - Цвет: Красный, Скорость: 50, Уровень топлива: 120
// Вторая машина - Цвет: Синий, Скорость: 70, Уровень топлива: 130

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
public class Animal
{
    private string _AnimalType;
    private string _AnimalColor;
    private string _AnimalNumber;
    public static int _AnimalQuantity { get; private set; } = 0;
    

    public string AnimalType
    {
        get {return _AnimalType;}
        set {_AnimalType = value;}
    }

    public string AnimalColor
    {
        get {return _AnimalColor;}
        set {_AnimalColor = value;}
    }

    public string AnimalNumber
    {
        get {return _AnimalNumber;}
        set {_AnimalNumber = value;}
    }

    public Animal()
    {
        _AnimalQuantity++;
    }

    public static void AnimalQuantity()
    {
        Console.WriteLine("Общее количество животных равняется: " + _AnimalQuantity);
    }

}

public class Bear : Animal
{
    private int _RunningSpeed;

    public Bear() : base()
    {
        
    }

    public void RunningSpeed(int Speed)
    {
        this._RunningSpeed = Speed;
        Console.WriteLine($"Скорость бега : {Speed} км/ч.");
    }
}

public class Shark : Animal
{
    private int _SwimmingSpeed;

    public Shark() : base()
    {
        
    }

    public void SwimmingSpeed(int Speed)
    {
        this._SwimmingSpeed = Speed;
        Console.WriteLine($"Скорость плавания : {Speed} км/ч.");
    }
}

Bear BrownBear = new Bear();
BrownBear.AnimalType = "Бурый медведь";
BrownBear.AnimalColor = "Кориченевый";
BrownBear.AnimalNumber = "№1";

Bear Polarbear = new Bear();
Polarbear.AnimalType = "Полярный медведь";
Polarbear.AnimalColor = "Белый";
Polarbear.AnimalNumber = "№2";

Shark WhiteShark = new Shark();
WhiteShark.AnimalType = "Белая акула";
WhiteShark.AnimalColor = "Серый";
WhiteShark.AnimalNumber = "№3";

Shark Tigershark = new Shark();
Tigershark.AnimalType = "Тигровая акула";
Tigershark.AnimalColor = "Серый в полоску";
Tigershark.AnimalNumber = "№4";

Animal.AnimalQuantity();
Console.WriteLine($"Животное {BrownBear.AnimalNumber} - Вид: {BrownBear.AnimalType}, Цвет: {BrownBear.AnimalColor},");
BrownBear.RunningSpeed(50);

Console.WriteLine($"Животное {Polarbear.AnimalNumber} - Вид: {Polarbear.AnimalType}, Цвет: {Polarbear.AnimalType},");
Polarbear.RunningSpeed(40);

Console.WriteLine($"Животное {WhiteShark.AnimalNumber} - Вид: {WhiteShark.AnimalType}, Цвет: {WhiteShark.AnimalColor},");
WhiteShark.SwimmingSpeed(56);

Console.WriteLine($"Животное {Tigershark.AnimalNumber} - Вид: {Tigershark.AnimalType}, Цвет: {Tigershark.AnimalColor},");
Tigershark.SwimmingSpeed(53);
// Out:
// Общее количество животных равняется: 4
// Животное №1 - Вид: Бурый медведь, Цвет: Кориченевый,
// Скорость бега : 50 км/ч.
// Животное №2 - Вид: Полярный медведь, Цвет: Полярный медведь,
// Скорость бега : 40 км/ч.
// Животное №3 - Вид: Белая акула, Цвет: Серый,
// Скорость плавания : 56 км/ч.
// Животное №4 - Вид: Тигровая акула, Цвет: Серый в полоску,
// Скорость плавания : 53 км/ч.
